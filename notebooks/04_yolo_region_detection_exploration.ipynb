# %% [markdown]
# # Optional YOLO Region Detection Exploration
#
# This notebook is opt-in. It checks whether YOLO support is importable and whether a local model path has been configured. It never downloads models by default.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from utils.image.layout.detectors.yolo_figure import YOLOFigureDetector

YOLO_MODEL_PATH = None  # Example: PROJECT_ROOT / "models" / "figure-detector.pt"
SAMPLE_IMAGE_PATH = None

print("ultralytics available:", YOLOFigureDetector.available)
print("model path configured:", bool(YOLO_MODEL_PATH))

# %%
if not YOLOFigureDetector.available:
    print("Skipping: ultralytics is not installed.")
elif not YOLO_MODEL_PATH:
    print("Skipping: set YOLO_MODEL_PATH to a local model file to run this exploration.")
elif not Path(YOLO_MODEL_PATH).exists():
    print(f"Skipping: model file does not exist: {YOLO_MODEL_PATH}")
else:
    print("Ready to instantiate YOLOFigureDetector with an explicit local model path.")
    print("Keep this path opt-in; do not add downloads to tests or imports.")
